# %%
import re
import os

# %% [markdown]
# ### ---

# %%
global py_is
py_is = False

# 全局 代码区域定义

# %%
def py_is_fun( vv ):
    global py_is
    if vv == '``` py':
        py_is = True
        
    elif vv == '```': 
        py_is = False

# %% [markdown]
# ---

# %%
def input_w( file, value ):
    file.write('\n'+value+'\n')

# %%
input_value = {
    'h2': "## ",
    'start_tcode': "``` py\n",
    'end_code': '```\n'
}

# %%
Path = "../让你的Python优雅.md"
mkfileopen = open(Path)
lines = mkfileopen.readlines()
mkfileopen.close()
# 获得 文本文字

# %%
# 不需要改变，直接写入,开头匹配
res = [r"``` py", r"更好的方法", r"#", r"```", r'---','<!-- more -->']
# 匹配中文
def is_zh(line):
    xx      =   u"([\u4e00-\u9fff]+)"  
    pattern =   re.compile(xx)  
    results =   pattern.findall(line)
    return bool(results)
# 匹配中英文
def is_en_zh(line):
    xx      =   u"([\w\W]+[\u4e00-\u9fff]+)" 
    pattern =   re.compile(xx)  
    results =   pattern.findall(line)
    return len(results)

# %%
match_value_s = []

for k, line in enumerate(lines):
    for re_value in res:
        
        if line.isspace():
            # \n 换行 直接 插入
            match_value_s.append(line)
            print('直接原文空格\n',)
            break
        
        match_value = re.match( re_value, line.strip(), re.M|re.I)
        
        if match_value:
            
            # 代码开始—结束的区域固定
            # ``` py
            # ```
            if py_is and re_value == r'``` py':
                match_value_s.append(input_value['end_code'] + line)
                print('两个```py 代码',line)
                py_is_fun('```')
                break
            elif re_value == r'``` py':
                py_is_fun(re_value)
                match_value_s.append(line)
                print('本来开始代码',line)
                break
            elif re_value == r'```':
                match_value_s.append(line)
                print('本来结束代码',line)
                py_is_fun('```')
                break
            elif py_is:
                match_value_s.append(input_value['end_code'] + line)
                print('其他白名单前代码闭合',line)
                py_is_fun('```')
                break
            else:
                match_value_s.append(line)
                print('原文白名单',line)
                break
            
    else:
        
        # 有中文有英文，不做处理
        # 多个中文片段
        if is_en_zh(line) is not 0 or is_zh(line) > 1:
            if py_is:
                match_value_s.append(input_value['end_code'] + line)
                py_is_fun('```')
                print('end',line)
                
            else:
                match_value_s.append(line)
                print('原本中文或英文不用加',line)
                
        # 单个中文片段，加 h2
        elif is_zh(line) and is_zh(line) <= 1:
            if py_is:
                match_value_s.append(input_value['end_code'] + input_value['h2'] + line)
                py_is_fun('```')
                print('加h2+end',line)
                
            else:
                match_value_s.append(input_value['h2'] + line)
                print('加h2',line)                
        # 默认
        elif py_is == False:
            
            match_value_s.append( input_value['start_tcode'] + line)
            py_is_fun('``` py') 
            print('start', str(k), repr(line) )
        
        else:
            match_value_s.append(line)
            print('默认原文',line)
# Out:
# 原文白名单 ---
#
# 原本中文或英文不用加 title: 让你的Python优雅
#
# start 2 'thumbnail:\n'
# 默认原文 'http://tse2.mm.bing.net/th?id=OIP.HMoLaA0mOSlTzJRGppa0ZQEgEs&pid=15.1'
#
# 默认原文 date: 2017-09-16 09:28:28
#
# 默认原文 tags: [python, ]
#
# 默认原文 banner:
#
# 其他白名单前代码闭合 ---
#
# 直接原文空格
#
# 原本中文或英文不用加 参考译文来自：www.lightxue.com/transforming-code-into-beautiful-idiomatic-python
#
# 直接原文空格
#
# 原本中文或英文不用加 在Python社区文化的浇灌下，演化出了一种独特的代码风格，去指导如何正确地使用Python，这就是常说的pythonic。
#
# 直接原文空格
#
# 原本中文或英文不用加 Raymond Hettinger是Python核心开发者，本文提到的许多特性都是他开发的。同时他也是Python社区热忱的布道师，不遗余力地传授pythoni
#
# 原本中文或英文不用加 c之道。这篇文章是网友Jeff Paine整理的他在2013年美国的PyCon的演讲的笔记。
#
# 直接原文空格
#
# 原文白名单 ---
#
# 直接原文空格
#
# 原本中文或英文不用加 可下载 jupyter
#
# 原本中文或英文不用加 <a href="/uploadfolder/xxxx.txt" download >点击下载</a>
#
# 直接原文空格
#
# 原本中文或英文不用加 以下正文
#
# 直接原文空格
#
# 原文白名单 ---
#
# 直接原文空格
#
# 原文白名单 ## 遍历一个范围内的数字
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 for i in [0, 1, 2, 3, 4, 5]:
#
# 默认原文     print i ** 2
#
# 直接原文空格
#
# 默认原文 for i in range(6):
#
# 默认原文     print i ** 2
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原文白名单 更好的方法
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 for i in xrange(6):
#
# 默认原文     print i ** 2
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原本中文或英文不用加 xrange会返回一个迭代器，用来一次
#
# 原本中文或英文不用加 遍历一个范围。这种方式会比range更省内存。xrange在Python 3中已经改名为range。
#
# 直接原文空格
#
# 原文白名单 ## 遍历一个集合
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 colors = ['red', 'green', 'blue', 'yellow']
#
# 直接原文空格
#
# 默认原文 for i in range(len(colors)):
#
# 默认原文     print colors[i]
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原文白名单 更好的方法
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 for color in colors:
#
# 默认原文     print color
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原文白名单 ## 反向遍历
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 colors = ['red', 'green', 'blue', 'yellow']
#
# 直接原文空格
#
# 默认原文 for i in range(len(colors)-1, -1, -1):
#
# 默认原文     print colors[i]
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原文白名单 更好的方法
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 for color in reversed(colors):
#
# 默认原文     print color
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原文白名单 <!-- more -->
#
# 直接原文空格
#
# 原文白名单 ## 遍历一个集合及其下标
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 colors = ['red', 'green', 'blue', 'yellow']
#
# 直接原文空格
#
# 默认原文 for i in range(len(colors)):
#
# 默认原文     print i, '--->', colors[i]
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原文白名单 更好的方法
#
# 直接原文空格
#
# 本来开始代码 ``` py
#
# 默认原文 for i, color in enumerate(colors):
#
# 默认原文     print i, '--->', color
#
# 本来结束代码 ```
#
# 直接原文空格
#
# 原本中文或英文不用加 这种写法效率高，优雅，而且帮你省去亲自创建和自增下标。
#
# 直接原文空格
#
# 原本中文或英文不用加 当你发现你在操作集合的下标时，你很有可能在做错事。
#
# 直接原文空格
#
# 直接原文空格
#
# 原文白名单 ## 遍历两个集合
#
# 直接原文空格
#
# start 102 "names = ['raymond', 'rachel', 'matthew']\n"
# 默认原文 colors = ['red', 'green', 'blue', 'yellow']
#
# 直接原文空格
#
# 默认原文 n = min(len(names), len(colors))
#
# 默认原文 for i in range(n):
#
# 默认原文     print names[i], '--->', colors[i]
#
# 直接原文空格
#
# 默认原文 for name, color in zip(names, colors):
#
# 默认原文     print name, '--->', color
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 114 'for name, color in izip(names, colors):\n'
# 默认原文     print name, '--->', color
#
# 直接原文空格
#
# end zip在内存中生成一个新的列表，需要更多的内存。izip比zip效率更高。
#
# 直接原文空格
#
# 原本中文或英文不用加 注意：在Python 3中，izip改名为zip，并替换了原来的zip成为内置函数。
#
# 直接原文空格
#
# 原本中文或英文不用加 有序地遍历
#
# 直接原文空格
#
# start 123 "colors = ['red', 'green', 'blue', 'yellow']\n"
# 直接原文空格
#
# 其他白名单前代码闭合 # 正序
#
# start 126 'for color in sorted(colors):\n'
# 默认原文     print colors
#
# 直接原文空格
#
# 其他白名单前代码闭合 # 倒序
#
# start 130 'for color in sorted(colors, reverse=True):\n'
# 默认原文     print colors
#
# 直接原文空格
#
# end 自定义排序顺序
#
# 直接原文空格
#
# start 135 "colors = ['red', 'green', 'blue', 'yellow']\n"
# 直接原文空格
#
# 默认原文 def compare_length(c1, c2):
#
# 默认原文     if len(c1) < len(c2): return -1
#
# 默认原文     if len(c1) > len(c2): return 1
#
# 默认原文     return 0
#
# 直接原文空格
#
# 默认原文 print sorted(colors, cmp=compare_length)
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 146 'print sorted(colors, key=len)\n'
# 直接原文空格
#
# end 第一种方法效率低而且写起来很不爽。另外，Python 3已经不支持比较函数了。
#
# 直接原文空格
#
# 原本中文或英文不用加 调用一个函数直到遇到标记值
#
# 直接原文空格
#
# start 152 'blocks = []\n'
# 默认原文 while True:
#
# 默认原文     block = f.read(32)
#
# 默认原文     if block == '':
#
# 默认原文         break
#
# 默认原文     blocks.append(block)
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 161 'blocks = []\n'
# 默认原文 for block in iter(partial(f.read, 32), ''):
#
# 默认原文     blocks.append(block)
#
# 直接原文空格
#
# end iter接受两个参数。第一个是你反复调用的函数，第二个是标记值。
#
# 直接原文空格
#
# 原本中文或英文不用加 译注：这个例子里不太能看出来方法二的优势，甚至觉得partial让代码可读性更差了。方法二的优势在于iter的返回值是个迭代器，迭代器能用在各种地方，set，s
#
# start 168 'orted，min，max，heapq，sum……\n'
# 直接原文空格
#
# end 在循环内识别多个退出点
#
# 直接原文空格
#
# start 172 'def find(seq, target):\n'
# 默认原文     found = False
#
# 默认原文     for i, value in enumerate(seq):
#
# 默认原文         if value == target:
#
# 默认原文             found = True
#
# 默认原文             break
#
# 默认原文     if not found:
#
# 默认原文         return -1
#
# 默认原文     return i
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 184 'def find(seq, target):\n'
# 默认原文     for i, value in enumerate(seq):
#
# 默认原文         if value == target:
#
# 默认原文             break
#
# 默认原文     else:
#
# 默认原文         return -1
#
# 默认原文     return i
#
# 直接原文空格
#
# end for执行完所有的循环后就会执行else。
#
# 直接原文空格
#
# 原本中文或英文不用加 译注：刚了解for-else语法时会困惑，什么情况下会执行到else里。有两种方法去理解else。传统的方法是把for看作if，当for后面的条件为False时
#
# 原本中文或英文不用加 执行else。其实条件为False时，就是for循环没被break出去，把所有循环都跑完的时候。所以另一种方法就是把else记成nobreak，当for没有被b
#
# 原本中文或英文不用加 reak，那么循环结束时会进入到else。
#
# 直接原文空格
#
# 原本中文或英文不用加 遍历字典的key
#
# 直接原文空格
#
# start 200 "d = {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}\n"
# 直接原文空格
#
# 默认原文 for k in d:
#
# 默认原文     print k
#
# 直接原文空格
#
# 默认原文 for k in d.keys():
#
# 默认原文     if k.startswith('r'):
#
# 默认原文         del d[k]
#
# 直接原文空格
#
# end 什么时候应该使用第二种而不是第一种方法？当你需要修改字典的时候。
#
# 直接原文空格
#
# 原本中文或英文不用加 如果你在迭代一个东西的时候修改它，那就是在冒天下之大不韪，接下来发生什么都活该。
#
# 直接原文空格
#
# 原本中文或英文不用加 d.keys()把字典里所有的key都复制到一个列表里。然后你就可以修改字典了。
#
# 直接原文空格
#
# 原本中文或英文不用加 注意：如果在Python
#
# 原本中文或英文不用加 3里迭代一个字典你得显示地写：list(d.keys())，因为d.keys()返回的是一个“字典视图”(一个提供字典key的动态视图的迭代器)。详情请看文档。
#
# 直接原文空格
#
# 原本中文或英文不用加 遍历一个字典的key和value
#
# 直接原文空格
#
# 原文白名单 # 并不快，每次必须要重新哈希并做一次查找
#
# start 221 'for k in d:\n'
# 默认原文     print k, '--->', d[k]
#
# 直接原文空格
#
# 其他白名单前代码闭合 # 产生一个很大的列表
#
# start 225 'for k, v in d.items():\n'
# 默认原文     print k, '--->', v
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 230 'for k, v in d.iteritems():\n'
# 默认原文     print k, '--->', v
#
# 直接原文空格
#
# end iteritems()更好是因为它返回了一个迭代器。
#
# 直接原文空格
#
# 原本中文或英文不用加 注意：Python 3已经没有iteritems()了，items()的行为和iteritems()很接近。详情请看文档。
#
# 直接原文空格
#
# 原本中文或英文不用加 用key-value对构建字典
#
# 直接原文空格
#
# start 239 "names = ['raymond', 'rachel', 'matthew']\n"
# 默认原文 colors = ['red', 'green', 'blue']
#
# 直接原文空格
#
# 默认原文 d = dict(izip(names, colors))
#
# 其他白名单前代码闭合 # {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}
#
# 直接原文空格
#
# start 245 'Python 3: d = dict(zip(names, colors))\n'
# 直接原文空格
#
# end 用字典计数
#
# 直接原文空格
#
# start 249 "colors = ['red', 'green', 'red', 'blue', 'green', 'red']\n"
# 直接原文空格
#
# 其他白名单前代码闭合 # 简单，基本的计数方法。适合初学者起步时学习。
#
# start 252 'd = {}\n'
# 默认原文 for color in colors:
#
# 默认原文     if color not in d:
#
# 默认原文         d[color] = 0
#
# 默认原文     d[color] += 1
#
# 直接原文空格
#
# 其他白名单前代码闭合 # {'blue': 1, 'green': 2, 'red': 3}
#
# 直接原文空格
#
# 原文白名单 更好的方法
#
# 直接原文空格
#
# start 262 'd = {}\n'
# 默认原文 for color in colors:
#
# 默认原文     d[color] = d.get(color, 0) + 1
#
# 直接原文空格
#
# 其他白名单前代码闭合 # 稍微潮点的方法，但有些坑需要注意，适合熟练的老手。
#
# start 267 'd = defaultdict(int)\n'
# 默认原文 for color in colors:
#
# 默认原文     d[color] += 1
#
# 直接原文空格
#
# end 用字典分组 — 第I部分和第II部分
#
# 直接原文空格
#
# start 273 "names = ['raymond', 'rachel', 'matthew', 'roger',\n"
# 默认原文          'betty', 'melissa', 'judith', 'charlie']
#
# 直接原文空格
#
# 其他白名单前代码闭合 # 在这个例子，我们按name的长度分组
#
# start 277 'd = {}\n'
# 默认原文 for name in names:
#
# 默认原文     key = len(name)
#
# 默认原文     if key not in d:
#
# 默认原文         d[key] = []
#
# 默认原文     d[key].append(name)
#
# 直接原文空格
#
# 其他白名单前代码闭合 # {5: ['roger', 'betty'], 6: ['rachel', 'judith'], 7: ['raymond', 'matthew',
#
# start 285 "'melissa', 'charlie']}\n"
# 直接原文空格
#
# 默认原文 d = {}
#
# 默认原文 for name in names:
#
# 默认原文     key = len(name)
#
# 默认原文     d.setdefault(key, []).append(name)
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 294 'd = defaultdict(list)\n'
# 默认原文 for name in names:
#
# 默认原文     key = len(name)
#
# 默认原文     d[key].append(name)
#
# 直接原文空格
#
# end 字典的popitem()是原子的吗？
#
# 直接原文空格
#
# start 301 "d = {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}\n"
# 直接原文空格
#
# 默认原文 while d:
#
# 默认原文     key, value = d.popitem()
#
# 默认原文     print key, '-->', value
#
# 直接原文空格
#
# end popitem是原子的，所以多线程的时候没必要用锁包着它。
#
# 直接原文空格
#
# 原本中文或英文不用加 连接字典
#
# 直接原文空格
#
# start 311 "defaults = {'color': 'red', 'user': 'guest'}\n"
# 默认原文 parser = argparse.ArgumentParser()
#
# 默认原文 parser.add_argument('-u', '--user')
#
# 默认原文 parser.add_argument('-c', '--color')
#
# 默认原文 namespace = parser.parse_args([])
#
# 默认原文 command_line_args = {k: v for k, v in vars(namespace).items() if v}
#
# 直接原文空格
#
# 其他白名单前代码闭合 # 下面是通常的作法，默认使用第一个字典，接着用环境变量覆盖它，最后用命令行参数覆盖它。
#
# 原文白名单 # 然而不幸的是，这种方法拷贝数据太疯狂。
#
# start 320 'd = defaults.copy()\n'
# 默认原文 d.update(os.environ)
#
# 默认原文 d.update(command_line_args)
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 326 'd = ChainMap(command_line_args, os.environ, defaults)\n'
# 直接原文空格
#
# end ChainMap在Python 3中加入。高效而优雅。
#
# 直接原文空格
#
# 原本中文或英文不用加 提高可读性
#
# 直接原文空格
#
# 原本中文或英文不用加 位置参数和下标很漂亮
#
# 原本中文或英文不用加 但关键字和名称更好
#
# 原本中文或英文不用加 第一种方法对计算机来说很便利
#
# 原本中文或英文不用加 第二种方法和人类思考方式一致
#
# 直接原文空格
#
# 原本中文或英文不用加 用关键字参数提高函数调用的可读性
#
# 直接原文空格
#
# start 339 "twitter_search('@obama', False, 20, True)\n"
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 343 "twitter_search('@obama', retweets=False, numtweets=20, popular=True)\n"
# 直接原文空格
#
# end 第二种方法稍微(微秒级)慢一点，但为了代码的可读性和开发时间，值得。
#
# 直接原文空格
#
# 原本中文或英文不用加 用namedtuple提高多个返回值的可读性
#
# 直接原文空格
#
# 原文白名单 # 老的testmod返回值
#
# start 350 'doctest.testmod()\n'
# 其他白名单前代码闭合 # (0, 4)
#
# 原文白名单 # 测试结果是好是坏？你看不出来，因为返回值不清晰。
#
# 直接原文空格
#
# 原文白名单 更好的方法
#
# 直接原文空格
#
# 原文白名单 # 新的testmod返回值, 一个namedtuple
#
# start 357 'doctest.testmod()\n'
# 其他白名单前代码闭合 # TestResults(failed=0, attempted=4)
#
# 直接原文空格
#
# 原本中文或英文不用加 namedtuple是tuple的子类，所以仍适用正常的元组操作，但它更友好。
#
# 直接原文空格
#
# 原本中文或英文不用加 创建一个nametuple
#
# 直接原文空格
#
# start 364 "TestResults = namedTuple('TestResults', ['failed', 'attempted'])\n"
# 直接原文空格
#
# end unpack序列
#
# 直接原文空格
#
# start 368 "p = 'Raymond', 'Hettinger', 0x30, 'python@example.com'\n"
# 直接原文空格
#
# 其他白名单前代码闭合 # 其它语言的常用方法/习惯
#
# start 371 'fname = p[0]\n'
# 默认原文 lname = p[1]
#
# 默认原文 age = p[2]
#
# 默认原文 email = p[3]
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 378 'fname, lname, age, email = p\n'
# 直接原文空格
#
# end 第二种方法用了unpack元组，更快，可读性更好。
#
# 直接原文空格
#
# 原本中文或英文不用加 更新多个变量的状态
#
# 直接原文空格
#
# start 384 'def fibonacci(n):\n'
# 默认原文     x = 0
#
# 默认原文     y = 1
#
# 默认原文     for i in range(n):
#
# 默认原文         print x
#
# 默认原文         t = y
#
# 默认原文         y = x + y
#
# 默认原文         x = t
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 395 'def fibonacci(n):\n'
# 默认原文     x, y = 0, 1
#
# 默认原文     for i in range(n):
#
# 默认原文         print x
#
# 默认原文         x, y = y, x + y
#
# 直接原文空格
#
# end 第一种方法的问题
#
# 直接原文空格
#
# 原本中文或英文不用加 x和y是状态，状态应该在一次操作中更新，分几行的话状态会互相对不上，这经常是bug的源头。
#
# 原本中文或英文不用加 操作有顺序要求
#
# 原本中文或英文不用加 太底层太细节
#
# 直接原文空格
#
# 原本中文或英文不用加 第二种方法抽象层级更高，没有操作顺序出错的风险而且更效率更高。
#
# 直接原文空格
#
# 原本中文或英文不用加 同时状态更新
#
# 直接原文空格
#
# start 411 'tmp_x = x + dx * t\n'
# 默认原文 tmp_y = y + dy * t
#
# 默认原文 tmp_dx = influence(m, x, y, dx, dy, partial='x')
#
# 默认原文 tmp_dy = influence(m, x, y, dx, dy, partial='y')
#
# 默认原文 x = tmp_x
#
# 默认原文 y = tmp_y
#
# 默认原文 dx = tmp_dx
#
# 默认原文 dy = tmp_dy
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 422 'x, y, dx, dy = (x + dx * t,\n'
# 默认原文                 y + dy * t,
#
# 默认原文                 influence(m, x, y, dx, dy, partial='x'),
#
# 默认原文                 influence(m, x, y, dx, dy, partial='y'))
#
# 直接原文空格
#
# end 效率
#
# 直接原文空格
#
# 原本中文或英文不用加 优化的基本原则
#
# 原本中文或英文不用加 除非必要，别无故移动数据
#
# 原本中文或英文不用加 稍微注意一下用线性的操作取代O(n**2)的操作
#
# 直接原文空格
#
# 原本中文或英文不用加 总的来说，不要无故移动数据
#
# 直接原文空格
#
# 原本中文或英文不用加 连接字符串
#
# 直接原文空格
#
# start 437 "names = ['raymond', 'rachel', 'matthew', 'roger',\n"
# 默认原文          'betty', 'melissa', 'judith', 'charlie']
#
# 直接原文空格
#
# 默认原文 s = names[0]
#
# 默认原文 for name in names[1:]:
#
# 默认原文     s += ', ' + name
#
# 默认原文 print s
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 447 "print ', '.join(names)\n"
# 直接原文空格
#
# end 更新序列
#
# 直接原文空格
#
# start 451 "names = ['raymond', 'rachel', 'matthew', 'roger',\n"
# 默认原文          'betty', 'melissa', 'judith', 'charlie']
#
# 直接原文空格
#
# 默认原文 del names[0]
#
# 其他白名单前代码闭合 # 下面的代码标志着你用错了数据结构
#
# start 456 'names.pop(0)\n'
# 默认原文 names.insert(0, 'mark')
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 461 "names = deque(['raymond', 'rachel', 'matthew', 'roger',\n"
# 默认原文                'betty', 'melissa', 'judith', 'charlie'])
#
# 直接原文空格
#
# 其他白名单前代码闭合 # 用deque更有效率
#
# start 465 'del names[0]\n'
# 默认原文 names.popleft()
#
# 默认原文 names.appendleft('mark')
#
# 直接原文空格
#
# end 装饰器和上下文管理
#
# 直接原文空格
#
# 原本中文或英文不用加 用于把业务和管理的逻辑分开
#
# 原本中文或英文不用加 分解代码和提高代码重用性的干净优雅的好工具
#
# 原本中文或英文不用加 起个好名字很关键
#
# 原本中文或英文不用加 记住蜘蛛侠的格言：能力越大，责任越大
#
# 直接原文空格
#
# 原本中文或英文不用加 使用装饰器分离出管理逻辑
#
# 直接原文空格
#
# 原文白名单 # 混着业务和管理逻辑，无法重用
#
# start 479 'def web_lookup(url, saved={}):\n'
# 默认原文     if url in saved:
#
# 默认原文         return saved[url]
#
# 默认原文     page = urllib.urlopen(url).read()
#
# 默认原文     saved[url] = page
#
# 默认原文     return page
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 488 '@cache\n'
# 默认原文 def web_lookup(url):
#
# 默认原文     return urllib.urlopen(url).read()
#
# 直接原文空格
#
# end 注意：Python 3.2开始加入了functools.lru_cache解决这个问题。
#
# 直接原文空格
#
# 原本中文或英文不用加 分离临时上下文
#
# 直接原文空格
#
# 原文白名单 # 保存旧的，创建新的
#
# start 497 'old_context = getcontext().copy()\n'
# 默认原文 getcontext().prec = 50
#
# 默认原文 print Decimal(355) / Decimal(113)
#
# 默认原文 setcontext(old_context)
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 504 'with localcontext(Context(prec=50)):\n'
# 默认原文     print Decimal(355) / Decimal(113)
#
# 直接原文空格
#
# end 译注：示例代码在使用标准库decimal，这个库已经实现好了localcontext。
#
# 直接原文空格
#
# 原本中文或英文不用加 如何打开关闭文件
#
# 直接原文空格
#
# start 511 "f = open('data.txt')\n"
# 默认原文 try:
#
# 默认原文     data = f.read()
#
# 默认原文 finally:
#
# 默认原文     f.close()
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 519 "with open('data.txt') as f:\n"
# 默认原文     data = f.read()
#
# 直接原文空格
#
# end 如何使用锁
#
# 直接原文空格
#
# 原文白名单 # 创建锁
#
# start 525 'lock = threading.Lock()\n'
# 直接原文空格
#
# 其他白名单前代码闭合 # 使用锁的老方法
#
# start 528 'lock.acquire()\n'
# 默认原文 try:
#
# 默认原文     print 'Critical section 1'
#
# 默认原文     print 'Critical section 2'
#
# 默认原文 finally:
#
# 默认原文     lock.release()
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# 原文白名单 # 使用锁的新方法
#
# start 538 'with lock:\n'
# 默认原文     print 'Critical section 1'
#
# 默认原文     print 'Critical section 2'
#
# 直接原文空格
#
# end 分离出临时的上下文
#
# 直接原文空格
#
# start 544 'try:\n'
# 默认原文     os.remove('somefile.tmp')
#
# 默认原文 except OSError:
#
# 默认原文     pass
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 551 'with ignored(OSError):\n'
# 默认原文     os.remove('somefile.tmp')
#
# 直接原文空格
#
# end ignored是Python 3.4加入的, 文档。
#
# 直接原文空格
#
# 原本中文或英文不用加 注意：ignored 实际上在标准库叫suppress(译注：contextlib.supress).
#
# 直接原文空格
#
# 原本中文或英文不用加 试试创建你自己的ignored上下文管理器。
#
# 直接原文空格
#
# start 560 '@contextmanager\n'
# 默认原文 def ignored(*exceptions):
#
# 默认原文     try:
#
# 默认原文         yield
#
# 默认原文     except exceptions:
#
# 默认原文         pass
#
# 直接原文空格
#
# end 把它放在你的工具目录，你也可以忽略异常
#
# 直接原文空格
#
# 原本中文或英文不用加 译注：contextmanager在标准库contextlib中，通过装饰生成器函数，省去用__enter__和__exit__写上下文管理器。详情请看文档。
#
# 直接原文空格
#
# 原本中文或英文不用加 分离临时上下文
#
# 直接原文空格
#
# 原文白名单 # 临时把标准输出重定向到一个文件，然后再恢复正常
#
# start 574 "with open('help.txt', 'w') as f:\n"
# 默认原文     oldstdout = sys.stdout
#
# 默认原文     sys.stdout = f
#
# 默认原文     try:
#
# 默认原文         help(pow)
#
# 默认原文     finally:
#
# 默认原文         sys.stdout = oldstdout
#
# 直接原文空格
#
# end 更好的写法
#
# 直接原文空格
#
# start 584 "with open('help.txt', 'w') as f:\n"
# 默认原文     with redirect_stdout(f):
#
# 默认原文         help(pow)
#
# 直接原文空格
#
# end redirect_stdout在Python 3.4加入(译注：contextlib.redirect_stdout)， bug反馈。
#
# 直接原文空格
#
# 原本中文或英文不用加 实现你自己的redirect_stdout上下文管理器。
#
# 直接原文空格
#
# start 592 '@contextmanager\n'
# 默认原文 def redirect_stdout(fileobj):
#
# 默认原文     oldstdout = sys.stdout
#
# 默认原文     sys.stdout = fileobj
#
# 默认原文     try:
#
# 默认原文         yield fieldobj
#
# 默认原文     finally:
#
# 默认原文         sys.stdout = oldstdout
#
# 直接原文空格
#
# end 简洁的单句表达
#
# 直接原文空格
#
# 原本中文或英文不用加 两个冲突的原则：
#
# 直接原文空格
#
# 原本中文或英文不用加 一行不要有太多逻辑
#
# 原本中文或英文不用加 不要把单一的想法拆分成多个部分
#
# 直接原文空格
#
# 原本中文或英文不用加 Raymond的原则：
#
# 直接原文空格
#
# 原本中文或英文不用加 一行代码的逻辑等价于一句自然语言
#
# 直接原文空格
#
# 原本中文或英文不用加 列表解析和生成器
#
# 直接原文空格
#
# start 614 'result = []\n'
# 默认原文 for i in range(10):
#
# 默认原文 s = i ** 2
#
# 默认原文     result.append(s)
#
# 默认原文 print sum(result)
#
# 直接原文空格
#
# 其他白名单前代码闭合 更好的方法
#
# 直接原文空格
#
# start 622 'print sum(i**2 for i in xrange(10))\n'
# 直接原文空格
#
# end 第一种方法说的是你在做什么，第二种方法说的是你想要什么。

# %%
for i in match_value_s:
    print(i)
# Out:
# ---
#
# title: 让你的Python优雅
#
# ``` py
# thumbnail:
#
# 'http://tse2.mm.bing.net/th?id=OIP.HMoLaA0mOSlTzJRGppa0ZQEgEs&pid=15.1'
#
# date: 2017-09-16 09:28:28
#
# tags: [python, ]
#
# banner:
#
# ```
# ---
#
#
#
# 参考译文来自：www.lightxue.com/transforming-code-into-beautiful-idiomatic-python
#
#
#
# 在Python社区文化的浇灌下，演化出了一种独特的代码风格，去指导如何正确地使用Python，这就是常说的pythonic。
#
#
#
# Raymond Hettinger是Python核心开发者，本文提到的许多特性都是他开发的。同时他也是Python社区热忱的布道师，不遗余力地传授pythoni
#
# c之道。这篇文章是网友Jeff Paine整理的他在2013年美国的PyCon的演讲的笔记。
#
#
#
# ---
#
#
#
# 可下载 jupyter
#
# <a href="/uploadfolder/xxxx.txt" download >点击下载</a>
#
#
#
# 以下正文
#
#
#
# ---
#
#
#
# ## 遍历一个范围内的数字
#
#
#
# ``` py
#
# for i in [0, 1, 2, 3, 4, 5]:
#
#     print i ** 2
#
#
#
# for i in range(6):
#
#     print i ** 2
#
# ```
#
#
#
# 更好的方法
#
#
#
# ``` py
#
# for i in xrange(6):
#
#     print i ** 2
#
# ```
#
#
#
# xrange会返回一个迭代器，用来一次
#
# 遍历一个范围。这种方式会比range更省内存。xrange在Python 3中已经改名为range。
#
#
#
# ## 遍历一个集合
#
#
#
# ``` py
#
# colors = ['red', 'green', 'blue', 'yellow']
#
#
#
# for i in range(len(colors)):
#
#     print colors[i]
#
# ```
#
#
#
# 更好的方法
#
#
#
# ``` py
#
# for color in colors:
#
#     print color
#
# ```
#
#
#
# ## 反向遍历
#
#
#
# ``` py
#
# colors = ['red', 'green', 'blue', 'yellow']
#
#
#
# for i in range(len(colors)-1, -1, -1):
#
#     print colors[i]
#
# ```
#
#
#
# 更好的方法
#
#
#
# ``` py
#
# for color in reversed(colors):
#
#     print color
#
# ```
#
#
#
# <!-- more -->
#
#
#
# ## 遍历一个集合及其下标
#
#
#
# ``` py
#
# colors = ['red', 'green', 'blue', 'yellow']
#
#
#
# for i in range(len(colors)):
#
#     print i, '--->', colors[i]
#
# ```
#
#
#
# 更好的方法
#
#
#
# ``` py
#
# for i, color in enumerate(colors):
#
#     print i, '--->', color
#
# ```
#
#
#
# 这种写法效率高，优雅，而且帮你省去亲自创建和自增下标。
#
#
#
# 当你发现你在操作集合的下标时，你很有可能在做错事。
#
#
#
#
#
# ## 遍历两个集合
#
#
#
# ``` py
# names = ['raymond', 'rachel', 'matthew']
#
# colors = ['red', 'green', 'blue', 'yellow']
#
#
#
# n = min(len(names), len(colors))
#
# for i in range(n):
#
#     print names[i], '--->', colors[i]
#
#
#
# for name, color in zip(names, colors):
#
#     print name, '--->', color
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# for name, color in izip(names, colors):
#
#     print name, '--->', color
#
#
#
# ```
# zip在内存中生成一个新的列表，需要更多的内存。izip比zip效率更高。
#
#
#
# 注意：在Python 3中，izip改名为zip，并替换了原来的zip成为内置函数。
#
#
#
# 有序地遍历
#
#
#
# ``` py
# colors = ['red', 'green', 'blue', 'yellow']
#
#
#
# ```
# # 正序
#
# ``` py
# for color in sorted(colors):
#
#     print colors
#
#
#
# ```
# # 倒序
#
# ``` py
# for color in sorted(colors, reverse=True):
#
#     print colors
#
#
#
# ```
# 自定义排序顺序
#
#
#
# ``` py
# colors = ['red', 'green', 'blue', 'yellow']
#
#
#
# def compare_length(c1, c2):
#
#     if len(c1) < len(c2): return -1
#
#     if len(c1) > len(c2): return 1
#
#     return 0
#
#
#
# print sorted(colors, cmp=compare_length)
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# print sorted(colors, key=len)
#
#
#
# ```
# 第一种方法效率低而且写起来很不爽。另外，Python 3已经不支持比较函数了。
#
#
#
# 调用一个函数直到遇到标记值
#
#
#
# ``` py
# blocks = []
#
# while True:
#
#     block = f.read(32)
#
#     if block == '':
#
#         break
#
#     blocks.append(block)
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# blocks = []
#
# for block in iter(partial(f.read, 32), ''):
#
#     blocks.append(block)
#
#
#
# ```
# iter接受两个参数。第一个是你反复调用的函数，第二个是标记值。
#
#
#
# 译注：这个例子里不太能看出来方法二的优势，甚至觉得partial让代码可读性更差了。方法二的优势在于iter的返回值是个迭代器，迭代器能用在各种地方，set，s
#
# ``` py
# orted，min，max，heapq，sum……
#
#
#
# ```
# 在循环内识别多个退出点
#
#
#
# ``` py
# def find(seq, target):
#
#     found = False
#
#     for i, value in enumerate(seq):
#
#         if value == target:
#
#             found = True
#
#             break
#
#     if not found:
#
#         return -1
#
#     return i
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# def find(seq, target):
#
#     for i, value in enumerate(seq):
#
#         if value == target:
#
#             break
#
#     else:
#
#         return -1
#
#     return i
#
#
#
# ```
# for执行完所有的循环后就会执行else。
#
#
#
# 译注：刚了解for-else语法时会困惑，什么情况下会执行到else里。有两种方法去理解else。传统的方法是把for看作if，当for后面的条件为False时
#
# 执行else。其实条件为False时，就是for循环没被break出去，把所有循环都跑完的时候。所以另一种方法就是把else记成nobreak，当for没有被b
#
# reak，那么循环结束时会进入到else。
#
#
#
# 遍历字典的key
#
#
#
# ``` py
# d = {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}
#
#
#
# for k in d:
#
#     print k
#
#
#
# for k in d.keys():
#
#     if k.startswith('r'):
#
#         del d[k]
#
#
#
# ```
# 什么时候应该使用第二种而不是第一种方法？当你需要修改字典的时候。
#
#
#
# 如果你在迭代一个东西的时候修改它，那就是在冒天下之大不韪，接下来发生什么都活该。
#
#
#
# d.keys()把字典里所有的key都复制到一个列表里。然后你就可以修改字典了。
#
#
#
# 注意：如果在Python
#
# 3里迭代一个字典你得显示地写：list(d.keys())，因为d.keys()返回的是一个“字典视图”(一个提供字典key的动态视图的迭代器)。详情请看文档。
#
#
#
# 遍历一个字典的key和value
#
#
#
# # 并不快，每次必须要重新哈希并做一次查找
#
# ``` py
# for k in d:
#
#     print k, '--->', d[k]
#
#
#
# ```
# # 产生一个很大的列表
#
# ``` py
# for k, v in d.items():
#
#     print k, '--->', v
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# for k, v in d.iteritems():
#
#     print k, '--->', v
#
#
#
# ```
# iteritems()更好是因为它返回了一个迭代器。
#
#
#
# 注意：Python 3已经没有iteritems()了，items()的行为和iteritems()很接近。详情请看文档。
#
#
#
# 用key-value对构建字典
#
#
#
# ``` py
# names = ['raymond', 'rachel', 'matthew']
#
# colors = ['red', 'green', 'blue']
#
#
#
# d = dict(izip(names, colors))
#
# ```
# # {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}
#
#
#
# ``` py
# Python 3: d = dict(zip(names, colors))
#
#
#
# ```
# 用字典计数
#
#
#
# ``` py
# colors = ['red', 'green', 'red', 'blue', 'green', 'red']
#
#
#
# ```
# # 简单，基本的计数方法。适合初学者起步时学习。
#
# ``` py
# d = {}
#
# for color in colors:
#
#     if color not in d:
#
#         d[color] = 0
#
#     d[color] += 1
#
#
#
# ```
# # {'blue': 1, 'green': 2, 'red': 3}
#
#
#
# 更好的方法
#
#
#
# ``` py
# d = {}
#
# for color in colors:
#
#     d[color] = d.get(color, 0) + 1
#
#
#
# ```
# # 稍微潮点的方法，但有些坑需要注意，适合熟练的老手。
#
# ``` py
# d = defaultdict(int)
#
# for color in colors:
#
#     d[color] += 1
#
#
#
# ```
# 用字典分组 — 第I部分和第II部分
#
#
#
# ``` py
# names = ['raymond', 'rachel', 'matthew', 'roger',
#
#          'betty', 'melissa', 'judith', 'charlie']
#
#
#
# ```
# # 在这个例子，我们按name的长度分组
#
# ``` py
# d = {}
#
# for name in names:
#
#     key = len(name)
#
#     if key not in d:
#
#         d[key] = []
#
#     d[key].append(name)
#
#
#
# ```
# # {5: ['roger', 'betty'], 6: ['rachel', 'judith'], 7: ['raymond', 'matthew',
#
# ``` py
# 'melissa', 'charlie']}
#
#
#
# d = {}
#
# for name in names:
#
#     key = len(name)
#
#     d.setdefault(key, []).append(name)
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# d = defaultdict(list)
#
# for name in names:
#
#     key = len(name)
#
#     d[key].append(name)
#
#
#
# ```
# 字典的popitem()是原子的吗？
#
#
#
# ``` py
# d = {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}
#
#
#
# while d:
#
#     key, value = d.popitem()
#
#     print key, '-->', value
#
#
#
# ```
# popitem是原子的，所以多线程的时候没必要用锁包着它。
#
#
#
# 连接字典
#
#
#
# ``` py
# defaults = {'color': 'red', 'user': 'guest'}
#
# parser = argparse.ArgumentParser()
#
# parser.add_argument('-u', '--user')
#
# parser.add_argument('-c', '--color')
#
# namespace = parser.parse_args([])
#
# command_line_args = {k: v for k, v in vars(namespace).items() if v}
#
#
#
# ```
# # 下面是通常的作法，默认使用第一个字典，接着用环境变量覆盖它，最后用命令行参数覆盖它。
#
# # 然而不幸的是，这种方法拷贝数据太疯狂。
#
# ``` py
# d = defaults.copy()
#
# d.update(os.environ)
#
# d.update(command_line_args)
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# d = ChainMap(command_line_args, os.environ, defaults)
#
#
#
# ```
# ChainMap在Python 3中加入。高效而优雅。
#
#
#
# 提高可读性
#
#
#
# 位置参数和下标很漂亮
#
# 但关键字和名称更好
#
# 第一种方法对计算机来说很便利
#
# 第二种方法和人类思考方式一致
#
#
#
# 用关键字参数提高函数调用的可读性
#
#
#
# ``` py
# twitter_search('@obama', False, 20, True)
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# twitter_search('@obama', retweets=False, numtweets=20, popular=True)
#
#
#
# ```
# 第二种方法稍微(微秒级)慢一点，但为了代码的可读性和开发时间，值得。
#
#
#
# 用namedtuple提高多个返回值的可读性
#
#
#
# # 老的testmod返回值
#
# ``` py
# doctest.testmod()
#
# ```
# # (0, 4)
#
# # 测试结果是好是坏？你看不出来，因为返回值不清晰。
#
#
#
# 更好的方法
#
#
#
# # 新的testmod返回值, 一个namedtuple
#
# ``` py
# doctest.testmod()
#
# ```
# # TestResults(failed=0, attempted=4)
#
#
#
# namedtuple是tuple的子类，所以仍适用正常的元组操作，但它更友好。
#
#
#
# 创建一个nametuple
#
#
#
# ``` py
# TestResults = namedTuple('TestResults', ['failed', 'attempted'])
#
#
#
# ```
# unpack序列
#
#
#
# ``` py
# p = 'Raymond', 'Hettinger', 0x30, 'python@example.com'
#
#
#
# ```
# # 其它语言的常用方法/习惯
#
# ``` py
# fname = p[0]
#
# lname = p[1]
#
# age = p[2]
#
# email = p[3]
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# fname, lname, age, email = p
#
#
#
# ```
# 第二种方法用了unpack元组，更快，可读性更好。
#
#
#
# 更新多个变量的状态
#
#
#
# ``` py
# def fibonacci(n):
#
#     x = 0
#
#     y = 1
#
#     for i in range(n):
#
#         print x
#
#         t = y
#
#         y = x + y
#
#         x = t
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# def fibonacci(n):
#
#     x, y = 0, 1
#
#     for i in range(n):
#
#         print x
#
#         x, y = y, x + y
#
#
#
# ```
# 第一种方法的问题
#
#
#
# x和y是状态，状态应该在一次操作中更新，分几行的话状态会互相对不上，这经常是bug的源头。
#
# 操作有顺序要求
#
# 太底层太细节
#
#
#
# 第二种方法抽象层级更高，没有操作顺序出错的风险而且更效率更高。
#
#
#
# 同时状态更新
#
#
#
# ``` py
# tmp_x = x + dx * t
#
# tmp_y = y + dy * t
#
# tmp_dx = influence(m, x, y, dx, dy, partial='x')
#
# tmp_dy = influence(m, x, y, dx, dy, partial='y')
#
# x = tmp_x
#
# y = tmp_y
#
# dx = tmp_dx
#
# dy = tmp_dy
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# x, y, dx, dy = (x + dx * t,
#
#                 y + dy * t,
#
#                 influence(m, x, y, dx, dy, partial='x'),
#
#                 influence(m, x, y, dx, dy, partial='y'))
#
#
#
# ```
# 效率
#
#
#
# 优化的基本原则
#
# 除非必要，别无故移动数据
#
# 稍微注意一下用线性的操作取代O(n**2)的操作
#
#
#
# 总的来说，不要无故移动数据
#
#
#
# 连接字符串
#
#
#
# ``` py
# names = ['raymond', 'rachel', 'matthew', 'roger',
#
#          'betty', 'melissa', 'judith', 'charlie']
#
#
#
# s = names[0]
#
# for name in names[1:]:
#
#     s += ', ' + name
#
# print s
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# print ', '.join(names)
#
#
#
# ```
# 更新序列
#
#
#
# ``` py
# names = ['raymond', 'rachel', 'matthew', 'roger',
#
#          'betty', 'melissa', 'judith', 'charlie']
#
#
#
# del names[0]
#
# ```
# # 下面的代码标志着你用错了数据结构
#
# ``` py
# names.pop(0)
#
# names.insert(0, 'mark')
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# names = deque(['raymond', 'rachel', 'matthew', 'roger',
#
#                'betty', 'melissa', 'judith', 'charlie'])
#
#
#
# ```
# # 用deque更有效率
#
# ``` py
# del names[0]
#
# names.popleft()
#
# names.appendleft('mark')
#
#
#
# ```
# 装饰器和上下文管理
#
#
#
# 用于把业务和管理的逻辑分开
#
# 分解代码和提高代码重用性的干净优雅的好工具
#
# 起个好名字很关键
#
# 记住蜘蛛侠的格言：能力越大，责任越大
#
#
#
# 使用装饰器分离出管理逻辑
#
#
#
# # 混着业务和管理逻辑，无法重用
#
# ``` py
# def web_lookup(url, saved={}):
#
#     if url in saved:
#
#         return saved[url]
#
#     page = urllib.urlopen(url).read()
#
#     saved[url] = page
#
#     return page
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# @cache
#
# def web_lookup(url):
#
#     return urllib.urlopen(url).read()
#
#
#
# ```
# 注意：Python 3.2开始加入了functools.lru_cache解决这个问题。
#
#
#
# 分离临时上下文
#
#
#
# # 保存旧的，创建新的
#
# ``` py
# old_context = getcontext().copy()
#
# getcontext().prec = 50
#
# print Decimal(355) / Decimal(113)
#
# setcontext(old_context)
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# with localcontext(Context(prec=50)):
#
#     print Decimal(355) / Decimal(113)
#
#
#
# ```
# 译注：示例代码在使用标准库decimal，这个库已经实现好了localcontext。
#
#
#
# 如何打开关闭文件
#
#
#
# ``` py
# f = open('data.txt')
#
# try:
#
#     data = f.read()
#
# finally:
#
#     f.close()
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# with open('data.txt') as f:
#
#     data = f.read()
#
#
#
# ```
# 如何使用锁
#
#
#
# # 创建锁
#
# ``` py
# lock = threading.Lock()
#
#
#
# ```
# # 使用锁的老方法
#
# ``` py
# lock.acquire()
#
# try:
#
#     print 'Critical section 1'
#
#     print 'Critical section 2'
#
# finally:
#
#     lock.release()
#
#
#
# ```
# 更好的方法
#
#
#
# # 使用锁的新方法
#
# ``` py
# with lock:
#
#     print 'Critical section 1'
#
#     print 'Critical section 2'
#
#
#
# ```
# 分离出临时的上下文
#
#
#
# ``` py
# try:
#
#     os.remove('somefile.tmp')
#
# except OSError:
#
#     pass
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# with ignored(OSError):
#
#     os.remove('somefile.tmp')
#
#
#
# ```
# ignored是Python 3.4加入的, 文档。
#
#
#
# 注意：ignored 实际上在标准库叫suppress(译注：contextlib.supress).
#
#
#
# 试试创建你自己的ignored上下文管理器。
#
#
#
# ``` py
# @contextmanager
#
# def ignored(*exceptions):
#
#     try:
#
#         yield
#
#     except exceptions:
#
#         pass
#
#
#
# ```
# 把它放在你的工具目录，你也可以忽略异常
#
#
#
# 译注：contextmanager在标准库contextlib中，通过装饰生成器函数，省去用__enter__和__exit__写上下文管理器。详情请看文档。
#
#
#
# 分离临时上下文
#
#
#
# # 临时把标准输出重定向到一个文件，然后再恢复正常
#
# ``` py
# with open('help.txt', 'w') as f:
#
#     oldstdout = sys.stdout
#
#     sys.stdout = f
#
#     try:
#
#         help(pow)
#
#     finally:
#
#         sys.stdout = oldstdout
#
#
#
# ```
# 更好的写法
#
#
#
# ``` py
# with open('help.txt', 'w') as f:
#
#     with redirect_stdout(f):
#
#         help(pow)
#
#
#
# ```
# redirect_stdout在Python 3.4加入(译注：contextlib.redirect_stdout)， bug反馈。
#
#
#
# 实现你自己的redirect_stdout上下文管理器。
#
#
#
# ``` py
# @contextmanager
#
# def redirect_stdout(fileobj):
#
#     oldstdout = sys.stdout
#
#     sys.stdout = fileobj
#
#     try:
#
#         yield fieldobj
#
#     finally:
#
#         sys.stdout = oldstdout
#
#
#
# ```
# 简洁的单句表达
#
#
#
# 两个冲突的原则：
#
#
#
# 一行不要有太多逻辑
#
# 不要把单一的想法拆分成多个部分
#
#
#
# Raymond的原则：
#
#
#
# 一行代码的逻辑等价于一句自然语言
#
#
#
# 列表解析和生成器
#
#
#
# ``` py
# result = []
#
# for i in range(10):
#
# s = i ** 2
#
#     result.append(s)
#
# print sum(result)
#
#
#
# ```
# 更好的方法
#
#
#
# ``` py
# print sum(i**2 for i in xrange(10))
#
#
#
# ```
# 第一种方法说的是你在做什么，第二种方法说的是你想要什么。

# %%
match_value_s
# Out:
# ['---\n',
#  'title: 让你的Python优雅\n',
#  '``` py\nthumbnail:\n',
#  "'http://tse2.mm.bing.net/th?id=OIP.HMoLaA0mOSlTzJRGppa0ZQEgEs&pid=15.1'\n",
#  'date: 2017-09-16 09:28:28\n',
#  'tags: [python, ]\n',
#  'banner:\n',
#  '```\n---\n',
#  '\n',
#  '参考译文来自：www.lightxue.com/transforming-code-into-beautiful-idiomatic-python\n',
#  '\n',
#  '在Python社区文化的浇灌下，演化出了一种独特的代码风格，去指导如何正确地使用Python，这就是常说的pythonic。\n',
#  '\n',
#  'Raymond Hettinger是Python核心开发者，本文提到的许多特性都是他开发的。同时他也是Python社区热忱的布道师，不遗余力地传授pythoni\n',
#  'c之道。这篇文章是网友Jeff Paine整理的他在2013年美国的PyCon的演讲的笔记。\n',
#  '\n',
#  '---\n',
#  '\n',
#  '可下载 jupyter\n',
#  '<a href="/uploadfolder/xxxx.txt" download >点击下载</a>\n',
#  '\n',
#  '以下正文\n',
#  '\n',
#  '---\n',
#  '\n',
#  '## 遍历一个范围内的数字\n',
#  '\n',
#  '``` py\n',
#  'for i in [0, 1, 2, 3, 4, 5]:\n',
#  '    print i ** 2\n',
#  ' \n',
#  'for i in range(6):\n',
#  '    print i ** 2\n',
#  '```\n',
#  '\n',
#  '更好的方法\n',
#  '\n',
#  '``` py\n',
#  'for i in xrange(6):\n',
#  '    print i ** 2\n',
#  '```\n',
#  '\n',
#  'xrange会返回一个迭代器，用来一次\n',
#  '遍历一个范围。这种方式会比range更省内存。xrange在Python 3中已经改名为range。\n',
#  '\n',
#  '## 遍历一个集合\n',
#  '\n',
#  '``` py\n',
#  "colors = ['red', 'green', 'blue', 'yellow']\n",
#  ' \n',
#  'for i in range(len(colors)):\n',
#  '    print colors[i]\n',
#  '```\n',
#  '\n',
#  '更好的方法\n',
#  '\n',
#  '``` py\n',
#  'for color in colors:\n',
#  '    print color\n',
#  '```\n',
#  '\n',
#  '## 反向遍历\n',
#  '\n',
#  '``` py\n',
#  "colors = ['red', 'green', 'blue', 'yellow']\n",
#  ' \n',
#  'for i in range(len(colors)-1, -1, -1):\n',
#  '    print colors[i]\n',
#  '```\n',
#  '\n',
#  '更好的方法\n',
#  '\n',
#  '``` py\n',
#  'for color in reversed(colors):\n',
#  '    print color\n',
#  '```\n',
#  '\n',
#  '<!-- more -->\n',
#  '\n',
#  '## 遍历一个集合及其下标\n',
#  '\n',
#  '``` py\n',
#  "colors = ['red', 'green', 'blue', 'yellow']\n",
#  ' \n',
#  'for i in range(len(colors)):\n',
#  "    print i, '--->', colors[i]\n",
#  '```\n',
#  '\n',
#  '更好的方法\n',
#  '\n',
#  '``` py\n',
#  'for i, color in enumerate(colors):\n',
#  "    print i, '--->', color\n",
#  '```\n',
#  '\n',
#  '这种写法效率高，优雅，而且帮你省去亲自创建和自增下标。\n',
#  '\n',
#  '当你发现你在操作集合的下标时，你很有可能在做错事。\n',
#  '\n',
#  '\n',
#  '## 遍历两个集合\n',
#  '\n',
#  "``` py\nnames = ['raymond', 'rachel', 'matthew']\n",
#  "colors = ['red', 'green', 'blue', 'yellow']\n",
#  '\n',
#  'n = min(len(names), len(colors))\n',
#  'for i in range(n):\n',
#  "    print names[i], '--->', colors[i]\n",
#  '\n',
#  'for name, color in zip(names, colors):\n',
#  "    print name, '--->', color\n",
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nfor name, color in izip(names, colors):\n',
#  "    print name, '--->', color\n",
#  '\n',
#  '```\nzip在内存中生成一个新的列表，需要更多的内存。izip比zip效率更高。\n',
#  '\n',
#  '注意：在Python 3中，izip改名为zip，并替换了原来的zip成为内置函数。\n',
#  '\n',
#  '有序地遍历\n',
#  '\n',
#  "``` py\ncolors = ['red', 'green', 'blue', 'yellow']\n",
#  '\n',
#  '```\n# 正序\n',
#  '``` py\nfor color in sorted(colors):\n',
#  '    print colors\n',
#  '\n',
#  '```\n# 倒序\n',
#  '``` py\nfor color in sorted(colors, reverse=True):\n',
#  '    print colors\n',
#  '\n',
#  '```\n自定义排序顺序\n',
#  '\n',
#  "``` py\ncolors = ['red', 'green', 'blue', 'yellow']\n",
#  '\n',
#  'def compare_length(c1, c2):\n',
#  '    if len(c1) < len(c2): return -1\n',
#  '    if len(c1) > len(c2): return 1\n',
#  '    return 0\n',
#  '\n',
#  'print sorted(colors, cmp=compare_length)\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nprint sorted(colors, key=len)\n',
#  '\n',
#  '```\n第一种方法效率低而且写起来很不爽。另外，Python 3已经不支持比较函数了。\n',
#  '\n',
#  '调用一个函数直到遇到标记值\n',
#  '\n',
#  '``` py\nblocks = []\n',
#  'while True:\n',
#  '    block = f.read(32)\n',
#  "    if block == '':\n",
#  '        break\n',
#  '    blocks.append(block)\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nblocks = []\n',
#  "for block in iter(partial(f.read, 32), ''):\n",
#  '    blocks.append(block)\n',
#  '\n',
#  '```\niter接受两个参数。第一个是你反复调用的函数，第二个是标记值。\n',
#  '\n',
#  '译注：这个例子里不太能看出来方法二的优势，甚至觉得partial让代码可读性更差了。方法二的优势在于iter的返回值是个迭代器，迭代器能用在各种地方，set，s\n',
#  '``` py\norted，min，max，heapq，sum……\n',
#  '\n',
#  '```\n在循环内识别多个退出点\n',
#  '\n',
#  '``` py\ndef find(seq, target):\n',
#  '    found = False\n',
#  '    for i, value in enumerate(seq):\n',
#  '        if value == target:\n',
#  '            found = True\n',
#  '            break\n',
#  '    if not found:\n',
#  '        return -1\n',
#  '    return i\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\ndef find(seq, target):\n',
#  '    for i, value in enumerate(seq):\n',
#  '        if value == target:\n',
#  '            break\n',
#  '    else:\n',
#  '        return -1\n',
#  '    return i\n',
#  '\n',
#  '```\nfor执行完所有的循环后就会执行else。\n',
#  '\n',
#  '译注：刚了解for-else语法时会困惑，什么情况下会执行到else里。有两种方法去理解else。传统的方法是把for看作if，当for后面的条件为False时\n',
#  '执行else。其实条件为False时，就是for循环没被break出去，把所有循环都跑完的时候。所以另一种方法就是把else记成nobreak，当for没有被b\n',
#  'reak，那么循环结束时会进入到else。\n',
#  '\n',
#  '遍历字典的key\n',
#  '\n',
#  "``` py\nd = {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}\n",
#  '\n',
#  'for k in d:\n',
#  '    print k\n',
#  '\n',
#  'for k in d.keys():\n',
#  "    if k.startswith('r'):\n",
#  '        del d[k]\n',
#  '\n',
#  '```\n什么时候应该使用第二种而不是第一种方法？当你需要修改字典的时候。\n',
#  '\n',
#  '如果你在迭代一个东西的时候修改它，那就是在冒天下之大不韪，接下来发生什么都活该。\n',
#  '\n',
#  'd.keys()把字典里所有的key都复制到一个列表里。然后你就可以修改字典了。\n',
#  '\n',
#  '注意：如果在Python\n',
#  '3里迭代一个字典你得显示地写：list(d.keys())，因为d.keys()返回的是一个“字典视图”(一个提供字典key的动态视图的迭代器)。详情请看文档。\n',
#  '\n',
#  '遍历一个字典的key和value\n',
#  '\n',
#  '# 并不快，每次必须要重新哈希并做一次查找\n',
#  '``` py\nfor k in d:\n',
#  "    print k, '--->', d[k]\n",
#  '\n',
#  '```\n# 产生一个很大的列表\n',
#  '``` py\nfor k, v in d.items():\n',
#  "    print k, '--->', v\n",
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nfor k, v in d.iteritems():\n',
#  "    print k, '--->', v\n",
#  '\n',
#  '```\niteritems()更好是因为它返回了一个迭代器。\n',
#  '\n',
#  '注意：Python 3已经没有iteritems()了，items()的行为和iteritems()很接近。详情请看文档。\n',
#  '\n',
#  '用key-value对构建字典\n',
#  '\n',
#  "``` py\nnames = ['raymond', 'rachel', 'matthew']\n",
#  "colors = ['red', 'green', 'blue']\n",
#  '\n',
#  'd = dict(izip(names, colors))\n',
#  "```\n# {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}\n",
#  '\n',
#  '``` py\nPython 3: d = dict(zip(names, colors))\n',
#  '\n',
#  '```\n用字典计数\n',
#  '\n',
#  "``` py\ncolors = ['red', 'green', 'red', 'blue', 'green', 'red']\n",
#  '\n',
#  '```\n# 简单，基本的计数方法。适合初学者起步时学习。\n',
#  '``` py\nd = {}\n',
#  'for color in colors:\n',
#  '    if color not in d:\n',
#  '        d[color] = 0\n',
#  '    d[color] += 1\n',
#  '\n',
#  "```\n# {'blue': 1, 'green': 2, 'red': 3}\n",
#  '\n',
#  '更好的方法\n',
#  '\n',
#  '``` py\nd = {}\n',
#  'for color in colors:\n',
#  '    d[color] = d.get(color, 0) + 1\n',
#  '\n',
#  '```\n# 稍微潮点的方法，但有些坑需要注意，适合熟练的老手。\n',
#  '``` py\nd = defaultdict(int)\n',
#  'for color in colors:\n',
#  '    d[color] += 1\n',
#  '\n',
#  '```\n用字典分组 — 第I部分和第II部分\n',
#  '\n',
#  "``` py\nnames = ['raymond', 'rachel', 'matthew', 'roger',\n",
#  "         'betty', 'melissa', 'judith', 'charlie']\n",
#  '\n',
#  '```\n# 在这个例子，我们按name的长度分组\n',
#  '``` py\nd = {}\n',
#  'for name in names:\n',
#  '    key = len(name)\n',
#  '    if key not in d:\n',
#  '        d[key] = []\n',
#  '    d[key].append(name)\n',
#  '\n',
#  "```\n# {5: ['roger', 'betty'], 6: ['rachel', 'judith'], 7: ['raymond', 'matthew',\n",
#  "``` py\n'melissa', 'charlie']}\n",
#  '\n',
#  'd = {}\n',
#  'for name in names:\n',
#  '    key = len(name)\n',
#  '    d.setdefault(key, []).append(name)\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nd = defaultdict(list)\n',
#  'for name in names:\n',
#  '    key = len(name)\n',
#  '    d[key].append(name)\n',
#  '\n',
#  '```\n字典的popitem()是原子的吗？\n',
#  '\n',
#  "``` py\nd = {'matthew': 'blue', 'rachel': 'green', 'raymond': 'red'}\n",
#  '\n',
#  'while d:\n',
#  '    key, value = d.popitem()\n',
#  "    print key, '-->', value\n",
#  '\n',
#  '```\npopitem是原子的，所以多线程的时候没必要用锁包着它。\n',
#  '\n',
#  '连接字典\n',
#  '\n',
#  "``` py\ndefaults = {'color': 'red', 'user': 'guest'}\n",
#  'parser = argparse.ArgumentParser()\n',
#  "parser.add_argument('-u', '--user')\n",
#  "parser.add_argument('-c', '--color')\n",
#  'namespace = parser.parse_args([])\n',
#  'command_line_args = {k: v for k, v in vars(namespace).items() if v}\n',
#  '\n',
#  '```\n# 下面是通常的作法，默认使用第一个字典，接着用环境变量覆盖它，最后用命令行参数覆盖它。\n',
#  '# 然而不幸的是，这种方法拷贝数据太疯狂。\n',
#  '``` py\nd = defaults.copy()\n',
#  'd.update(os.environ)\n',
#  'd.update(command_line_args)\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nd = ChainMap(command_line_args, os.environ, defaults)\n',
#  '\n',
#  '```\nChainMap在Python 3中加入。高效而优雅。\n',
#  '\n',
#  '提高可读性\n',
#  '\n',
#  '位置参数和下标很漂亮\n',
#  '但关键字和名称更好\n',
#  '第一种方法对计算机来说很便利\n',
#  '第二种方法和人类思考方式一致\n',
#  '\n',
#  '用关键字参数提高函数调用的可读性\n',
#  '\n',
#  "``` py\ntwitter_search('@obama', False, 20, True)\n",
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  "``` py\ntwitter_search('@obama', retweets=False, numtweets=20, popular=True)\n",
#  '\n',
#  '```\n第二种方法稍微(微秒级)慢一点，但为了代码的可读性和开发时间，值得。\n',
#  '\n',
#  '用namedtuple提高多个返回值的可读性\n',
#  '\n',
#  '# 老的testmod返回值\n',
#  '``` py\ndoctest.testmod()\n',
#  '```\n# (0, 4)\n',
#  '# 测试结果是好是坏？你看不出来，因为返回值不清晰。\n',
#  '\n',
#  '更好的方法\n',
#  '\n',
#  '# 新的testmod返回值, 一个namedtuple\n',
#  '``` py\ndoctest.testmod()\n',
#  '```\n# TestResults(failed=0, attempted=4)\n',
#  '\n',
#  'namedtuple是tuple的子类，所以仍适用正常的元组操作，但它更友好。\n',
#  '\n',
#  '创建一个nametuple\n',
#  '\n',
#  "``` py\nTestResults = namedTuple('TestResults', ['failed', 'attempted'])\n",
#  '\n',
#  '```\nunpack序列\n',
#  '\n',
#  "``` py\np = 'Raymond', 'Hettinger', 0x30, 'python@example.com'\n",
#  '\n',
#  '```\n# 其它语言的常用方法/习惯\n',
#  '``` py\nfname = p[0]\n',
#  'lname = p[1]\n',
#  'age = p[2]\n',
#  'email = p[3]\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nfname, lname, age, email = p\n',
#  '\n',
#  '```\n第二种方法用了unpack元组，更快，可读性更好。\n',
#  '\n',
#  '更新多个变量的状态\n',
#  '\n',
#  '``` py\ndef fibonacci(n):\n',
#  '    x = 0\n',
#  '    y = 1\n',
#  '    for i in range(n):\n',
#  '        print x\n',
#  '        t = y\n',
#  '        y = x + y\n',
#  '        x = t\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\ndef fibonacci(n):\n',
#  '    x, y = 0, 1\n',
#  '    for i in range(n):\n',
#  '        print x\n',
#  '        x, y = y, x + y\n',
#  '\n',
#  '```\n第一种方法的问题\n',
#  '\n',
#  'x和y是状态，状态应该在一次操作中更新，分几行的话状态会互相对不上，这经常是bug的源头。\n',
#  '操作有顺序要求\n',
#  '太底层太细节\n',
#  '\n',
#  '第二种方法抽象层级更高，没有操作顺序出错的风险而且更效率更高。\n',
#  '\n',
#  '同时状态更新\n',
#  '\n',
#  '``` py\ntmp_x = x + dx * t\n',
#  'tmp_y = y + dy * t\n',
#  "tmp_dx = influence(m, x, y, dx, dy, partial='x')\n",
#  "tmp_dy = influence(m, x, y, dx, dy, partial='y')\n",
#  'x = tmp_x\n',
#  'y = tmp_y\n',
#  'dx = tmp_dx\n',
#  'dy = tmp_dy\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nx, y, dx, dy = (x + dx * t,\n',
#  '                y + dy * t,\n',
#  "                influence(m, x, y, dx, dy, partial='x'),\n",
#  "                influence(m, x, y, dx, dy, partial='y'))\n",
#  '\n',
#  '```\n效率\n',
#  '\n',
#  '优化的基本原则\n',
#  '除非必要，别无故移动数据\n',
#  '稍微注意一下用线性的操作取代O(n**2)的操作\n',
#  '\n',
#  '总的来说，不要无故移动数据\n',
#  '\n',
#  '连接字符串\n',
#  '\n',
#  "``` py\nnames = ['raymond', 'rachel', 'matthew', 'roger',\n",
#  "         'betty', 'melissa', 'judith', 'charlie']\n",
#  '\n',
#  's = names[0]\n',
#  'for name in names[1:]:\n',
#  "    s += ', ' + name\n",
#  'print s\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  "``` py\nprint ', '.join(names)\n",
#  '\n',
#  '```\n更新序列\n',
#  '\n',
#  "``` py\nnames = ['raymond', 'rachel', 'matthew', 'roger',\n",
#  "         'betty', 'melissa', 'judith', 'charlie']\n",
#  '\n',
#  'del names[0]\n',
#  '```\n# 下面的代码标志着你用错了数据结构\n',
#  '``` py\nnames.pop(0)\n',
#  "names.insert(0, 'mark')\n",
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  "``` py\nnames = deque(['raymond', 'rachel', 'matthew', 'roger',\n",
#  "               'betty', 'melissa', 'judith', 'charlie'])\n",
#  '\n',
#  '```\n# 用deque更有效率\n',
#  '``` py\ndel names[0]\n',
#  'names.popleft()\n',
#  "names.appendleft('mark')\n",
#  '\n',
#  '```\n装饰器和上下文管理\n',
#  '\n',
#  '用于把业务和管理的逻辑分开\n',
#  '分解代码和提高代码重用性的干净优雅的好工具\n',
#  '起个好名字很关键\n',
#  '记住蜘蛛侠的格言：能力越大，责任越大\n',
#  '\n',
#  '使用装饰器分离出管理逻辑\n',
#  '\n',
#  '# 混着业务和管理逻辑，无法重用\n',
#  '``` py\ndef web_lookup(url, saved={}):\n',
#  '    if url in saved:\n',
#  '        return saved[url]\n',
#  '    page = urllib.urlopen(url).read()\n',
#  '    saved[url] = page\n',
#  '    return page\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\n@cache\n',
#  'def web_lookup(url):\n',
#  '    return urllib.urlopen(url).read()\n',
#  '\n',
#  '```\n注意：Python 3.2开始加入了functools.lru_cache解决这个问题。\n',
#  '\n',
#  '分离临时上下文\n',
#  '\n',
#  '# 保存旧的，创建新的\n',
#  '``` py\nold_context = getcontext().copy()\n',
#  'getcontext().prec = 50\n',
#  'print Decimal(355) / Decimal(113)\n',
#  'setcontext(old_context)\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nwith localcontext(Context(prec=50)):\n',
#  '    print Decimal(355) / Decimal(113)\n',
#  '\n',
#  '```\n译注：示例代码在使用标准库decimal，这个库已经实现好了localcontext。\n',
#  '\n',
#  '如何打开关闭文件\n',
#  '\n',
#  "``` py\nf = open('data.txt')\n",
#  'try:\n',
#  '    data = f.read()\n',
#  'finally:\n',
#  '    f.close()\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  "``` py\nwith open('data.txt') as f:\n",
#  '    data = f.read()\n',
#  '\n',
#  '```\n如何使用锁\n',
#  '\n',
#  '# 创建锁\n',
#  '``` py\nlock = threading.Lock()\n',
#  '\n',
#  '```\n# 使用锁的老方法\n',
#  '``` py\nlock.acquire()\n',
#  'try:\n',
#  "    print 'Critical section 1'\n",
#  "    print 'Critical section 2'\n",
#  'finally:\n',
#  '    lock.release()\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '# 使用锁的新方法\n',
#  '``` py\nwith lock:\n',
#  "    print 'Critical section 1'\n",
#  "    print 'Critical section 2'\n",
#  '\n',
#  '```\n分离出临时的上下文\n',
#  '\n',
#  '``` py\ntry:\n',
#  "    os.remove('somefile.tmp')\n",
#  'except OSError:\n',
#  '    pass\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nwith ignored(OSError):\n',
#  "    os.remove('somefile.tmp')\n",
#  '\n',
#  '```\nignored是Python 3.4加入的, 文档。\n',
#  '\n',
#  '注意：ignored 实际上在标准库叫suppress(译注：contextlib.supress).\n',
#  '\n',
#  '试试创建你自己的ignored上下文管理器。\n',
#  '\n',
#  '``` py\n@contextmanager\n',
#  'def ignored(*exceptions):\n',
#  '    try:\n',
#  '        yield\n',
#  '    except exceptions:\n',
#  '        pass\n',
#  '\n',
#  '```\n把它放在你的工具目录，你也可以忽略异常\n',
#  '\n',
#  '译注：contextmanager在标准库contextlib中，通过装饰生成器函数，省去用__enter__和__exit__写上下文管理器。详情请看文档。\n',
#  '\n',
#  '分离临时上下文\n',
#  '\n',
#  '# 临时把标准输出重定向到一个文件，然后再恢复正常\n',
#  "``` py\nwith open('help.txt', 'w') as f:\n",
#  '    oldstdout = sys.stdout\n',
#  '    sys.stdout = f\n',
#  '    try:\n',
#  '        help(pow)\n',
#  '    finally:\n',
#  '        sys.stdout = oldstdout\n',
#  '\n',
#  '```\n更好的写法\n',
#  '\n',
#  "``` py\nwith open('help.txt', 'w') as f:\n",
#  '    with redirect_stdout(f):\n',
#  '        help(pow)\n',
#  '\n',
#  '```\nredirect_stdout在Python 3.4加入(译注：contextlib.redirect_stdout)， bug反馈。\n',
#  '\n',
#  '实现你自己的redirect_stdout上下文管理器。\n',
#  '\n',
#  '``` py\n@contextmanager\n',
#  'def redirect_stdout(fileobj):\n',
#  '    oldstdout = sys.stdout\n',
#  '    sys.stdout = fileobj\n',
#  '    try:\n',
#  '        yield fieldobj\n',
#  '    finally:\n',
#  '        sys.stdout = oldstdout\n',
#  '\n',
#  '```\n简洁的单句表达\n',
#  '\n',
#  '两个冲突的原则：\n',
#  '\n',
#  '一行不要有太多逻辑\n',
#  '不要把单一的想法拆分成多个部分\n',
#  '\n',
#  'Raymond的原则：\n',
#  '\n',
#  '一行代码的逻辑等价于一句自然语言\n',
#  '\n',
#  '列表解析和生成器\n',
#  '\n',
#  '``` py\nresult = []\n',
#  'for i in range(10):\n',
#  's = i ** 2\n',
#  '    result.append(s)\n',
#  'print sum(result)\n',
#  '\n',
#  '```\n更好的方法\n',
#  '\n',
#  '``` py\nprint sum(i**2 for i in xrange(10))\n',
#  '\n',
#  '```\n第一种方法说的是你在做什么，第二种方法说的是你想要什么。\n']

# %%
write_file = '../test_w.md'

file = open(write_file, 'w+')

# %%
all = ''
for i in match_value_s:
    file.write(i)

file.close()
print('{} file is create markdown from {}'.format(write_file, Path))
# Out:
# ../test_w.md file is create markdown from ../让你的Python优雅.md

# %% [markdown]
# ## 后记
